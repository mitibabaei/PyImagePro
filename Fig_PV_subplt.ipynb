# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img1 = mpimg.imread('../filaments/old/fil1_pv_velocity.png')
img2 = mpimg.imread('../filaments/old/fil2_pv_velocity.png')
img3 = mpimg.imread('../filaments/old/fil3_pv_velocity.png')
img4 = mpimg.imread('../filaments/old/fil4_pv_velocity.png')
img5 = mpimg.imread('../filaments/old/fil5_pv_velocity.png')
img6 = mpimg.imread('../filaments/old/fil7_pv_velocity.png')
img12 = mpimg.imread('plots/fil1_regression.png')
img22 = mpimg.imread('plots/fil2_regression.png')
img32 = mpimg.imread('plots/fil3_regression.png')
img42 = mpimg.imread('plots/fil4_regression.png')
img52 = mpimg.imread('plots/fil5_regression.png')
img62 = mpimg.imread('plots/fil7_regression.png')

# %%
fig, axs = plt.subplots(6, 2, figsize=(8, 15))


plt.subplot(621)
plt.imshow(img1)
plt.axis('off')

plt.subplot(622)
plt.imshow(img12)
plt.axis('off')

plt.subplot(623)
plt.imshow(img2)
plt.axis('off')

plt.subplot(624)
plt.imshow(img22)
plt.axis('off')

plt.subplot(625)
plt.imshow(img3)
plt.axis('off')

plt.subplot(626)
plt.imshow(img32)
plt.axis('off')

plt.subplot(627)
plt.imshow(img4)
plt.axis('off')

plt.subplot(628)
plt.imshow(img42)
plt.axis('off')


#plt.savefig('../filaments/old/pv_velocity.png')
plt.show()

# %%
fig, axs = plt.subplots(6, 2, figsize=(10, 25))
axs[0, 0].imshow(img1)
axs[0, 0].axis('off')
axs[0, 1].imshow(img12)
axs[0, 1].axis('off')
axs[1, 0].imshow(img2)
axs[1, 0].axis('off')
axs[1, 1].imshow(img22)
axs[1, 1].axis('off')
axs[2, 0].imshow(img3)
axs[2, 0].axis('off')
axs[2, 1].imshow(img32)
axs[2, 1].axis('off')
axs[3, 0].imshow(img4)
axs[3, 0].axis('off')
axs[3, 1].imshow(img42)
axs[3, 1].axis('off')
axs[4, 0].imshow(img5)
axs[4, 0].axis('off')
axs[4, 1].imshow(img52)
axs[4, 1].axis('off')
axs[5, 0].imshow(img6)
axs[5, 0].axis('off')
axs[5, 1].imshow(img62)
axs[5, 1].axis('off')
# Out:
# (-0.5, 3599.5, 1499.5, -0.5)
